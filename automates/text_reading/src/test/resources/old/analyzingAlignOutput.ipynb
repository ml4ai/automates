# %%
import json

# %%
with open('/home/alexeeva/Repos/automates/automates/text_reading/src/test/resources/temporaryAlignmentOutputSample.json') as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['full_text_equation', 'comment', 'parameter_setting_via_idfr', 'text_var', 'parameter_setting_via_cncpt', 'equation', 'source', 'unit_via_idfr', 'int_param_setting_via_idfr', 'gvar', 'links'])

# %%
for key in data.keys():
    for u in data[key]:
        print(u.keys())
# Out:
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# dict_keys(['uid', 'content'])
# ...

# %%
data["links"]
# Out:
# [{'element_1': 'a5270b9f-30d4-4d90-b2d4-3545a9971282::s_t',
#   'element_2': '56246bcf-c0aa-47f8-82aa-3b788e9b12c0::S_t         Current count of individuals that are susceptible to either disease',
#   'link_type': 'source_to_comment',
#   'score': 1},
#  {'element_1': 'a5270b9f-30d4-4d90-b2d4-3545a9971282::s_t',
#   'element_2': '79d52770-2b92-49b1-917a-72ca8a32d638::S_t         Current count of individuals that are susceptible to either disease',
#   'link_type': 'source_to_comment',
#   'score': 1},
#  {'element_1': 'a5270b9f-30d4-4d90-b2d4-3545a9971282::s_t',
#   'element_2': '2d429dff-26f6-436c-b37a-7b907640f16f::Ib_t        Current count of individuals that are infectious with disease B',
#   'link_type': 'source_to_comment',
#   'score': 0.3333333333333333},
#  {'element_1': '8972ee0e-14cc-4f07-812a-6f91a81aa915::s_t',
#   'element_2': '56246bcf-c0aa-47f8-82aa-3b788e9b12c0::S_t         Current count of individuals that are susceptible to either disease',
# ...

# %%
#get distinct list of elements and link types
# for every element, find all the links, then look them all up in a dict based on all the keys in link elements- shouldn't be too hard
# have a test for just reading in the json and checking keys or something - doesn't matter that the play framework doesn't work right now

# %%
# links: [{
#     gvaruid: 9999,
#     link_type1: {linkuid: score, linkuid:score} # sorted by score
#     link_type2: {linkuid: score, linkuid:score}
#     link_type3: null},
# ]

# %%
# gvar_id should have link type 1 non empty
# gvar_id should have link type 1 score > x 
# links length should be this many (or at least this many)

# cal score:
#
